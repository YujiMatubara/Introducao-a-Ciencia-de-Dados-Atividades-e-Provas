# %% [markdown]
# SCC-ICMC-USP - 2º Semestre de 2023
# SCC0275 - Introdução à Ciência de Dados
# Professora: Roseli A. F. Romero
# Monitor: Roseval Malaquias Jr
# Exercício 2
#
# Aluno:
#
# Lucas Yuji Matubara

# %%
# Download dos datasets para o ambiente virtual.
# !wget -O hepatitis.csv "https://drive.google.com/uc?export=download&id=1hYkarxPr0snIl-W7VWM9OxZdsOfuUwsU"
# Out:
# --2023-09-15 11:48:15--  https://drive.google.com/uc?export=download&id=1hYkarxPr0snIl-W7VWM9OxZdsOfuUwsU
# Resolving drive.google.com (drive.google.com)... 108.177.98.101, 108.177.98.113, 108.177.98.100, ...
# Connecting to drive.google.com (drive.google.com)|108.177.98.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-a0-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u3cmcui20krqsa0a13g9a3qo37lc27a2/1694778450000/17263126637575785733/*/1hYkarxPr0snIl-W7VWM9OxZdsOfuUwsU?e=download&uuid=adddbce1-1715-4553-913b-3afae649b765 [following]
# ...
# --2023-09-15 11:48:16--  https://doc-14-a0-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u3cmcui20krqsa0a13g9a3qo37lc27a2/1694778450000/17263126637575785733/*/1hYkarxPr0snIl-W7VWM9OxZdsOfuUwsU?e=download&uuid=adddbce1-1715-4553-913b-3afae649b765
# ...

# %% [markdown]
# Questão 01
#
# Carregue o dataset hepatitis.csv (pandas.read_csv) e interprete os valores ausentes corretamente. Utilize o parâmetro na_values='?'.

# %%
import pandas as pd

df = pd.read_csv('hepatitis.csv', na_values='?')

# %% [markdown]
# O parâmetro na_values define para NAN os valores contidos em ' '

# %%
df.head(3)
# Out:
#    AGE     SEX STEROID ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_BIG  \
# 0   30    male      no         no      no      no       no        no
# 1   50  female      no         no     yes      no       no        no
# 2   78  female     yes         no     yes      no       no       yes
#
#   LIVER_FIRM SPLEEN_PALPABLE SPIDERS ASCITES VARICES  BILIRUBIN  \
# 0         no              no      no      no      no        1.0
# 1         no              no      no      no      no        0.9
# 2         no              no      no      no      no        0.7
#
#    ALK_PHOSPHATE  SGOT  ALBUMIN  PROTIME HISTOLOGY  Class
# 0           85.0  18.0      4.0      NaN        no      1
# 1          135.0  42.0      3.5      NaN        no      1
# 2           96.0  32.0      4.0      NaN        no      1

# %%
mask_nan = df.isna().any(axis=1)
print(df[mask_nan])
# Out:
#      AGE     SEX STEROID ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_BIG  \
# 0     30    male      no         no      no      no       no        no
# 1     50  female      no         no     yes      no       no        no
# 2     78  female     yes         no     yes      no       no       yes
# 3     31  female     NaN        yes      no      no       no       yes
# 4     34  female     yes         no      no      no       no       yes
# ..   ...     ...     ...        ...     ...     ...      ...       ...
# 148   20  female      no         no      no      no       no       yes
# 149   36  female     yes         no      no      no       no       yes
# 150   46  female     yes         no     yes     yes      yes       yes
# 151   44  female     yes         no     yes      no       no       yes
# 152   61  female      no         no     yes     yes       no        no
#
#     LIVER_FIRM SPLEEN_PALPABLE SPIDERS ASCITES VARICES  BILIRUBIN  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AGE              155 non-null    int64
#  1   SEX              155 non-null    object
#  2   STEROID          154 non-null    object
#  3   ANTIVIRALS       155 non-null    object
#  4   FATIGUE          154 non-null    object
#  5   MALAISE          154 non-null    object
#  6   ANOREXIA         154 non-null    object
#  7   LIVER_BIG        145 non-null    object
#  8   LIVER_FIRM       144 non-null    object
#  9   SPLEEN_PALPABLE  150 non-null    object
#  10  SPIDERS          150 non-null    object
#  11  ASCITES          150 non-null    object
#  12  VARICES          150 non-null    object
#  13  BILIRUBIN        149 non-null    float64
#  14  ALK_PHOSPHATE    126 non-null    float64
#  15  SGOT             151 non-null    float64
# ...

# %% [markdown]
# Observamos que possuímos NAN em quase todos os valores, exceto por AGE, SEX, HISTOLOGY, e Class. Porém a presença de NAN é pequena em quase todos os atributos com exceção do PROTIME. Não podemos simplesmente descartá-los pois das 155 tuplas, 152 possuem valores NAN em pelo menos um atributo.

# %% [markdown]
# Questão 02
#
# Realize uma análise exploratória inicial do dataset fornecido.
#
# Para isso, você deve:
#
# Apresente a quantidade de valores faltantes para cada variável do dataset.
# Identifique o tipo de dado de cada uma das variáveis (se são numéricas ou categóricas).
# ATENÇÃO: O pandas pode importar as variáveis com os tipos incorretos!

# %%
df.isna().sum()
# Out:
# AGE                 0
# SEX                 0
# STEROID             1
# ANTIVIRALS          0
# FATIGUE             1
# MALAISE             1
# ANOREXIA            1
# LIVER_BIG          10
# LIVER_FIRM         11
# SPLEEN_PALPABLE     5
# SPIDERS             5
# ASCITES             5
# VARICES             5
# BILIRUBIN           6
# ALK_PHOSPHATE      29
# SGOT                4
# ALBUMIN            16
# PROTIME            67
# HISTOLOGY           0
# Class               0
# dtype: int64

# %%
df.dtypes
# Out:
# AGE                  int64
# SEX                 object
# STEROID             object
# ANTIVIRALS          object
# FATIGUE             object
# MALAISE             object
# ANOREXIA            object
# LIVER_BIG           object
# LIVER_FIRM          object
# SPLEEN_PALPABLE     object
# SPIDERS             object
# ASCITES             object
# VARICES             object
# BILIRUBIN          float64
# ALK_PHOSPHATE      float64
# SGOT               float64
# ALBUMIN            float64
# PROTIME            float64
# HISTOLOGY           object
# Class                int64
# dtype: object

# %%
df.head(3)
# Out:
#    AGE     SEX STEROID ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_BIG  \
# 0   30    male      no         no      no      no       no        no
# 1   50  female      no         no     yes      no       no        no
# 2   78  female     yes         no     yes      no       no       yes
#
#   LIVER_FIRM SPLEEN_PALPABLE SPIDERS ASCITES VARICES  BILIRUBIN  \
# 0         no              no      no      no      no        1.0
# 1         no              no      no      no      no        0.9
# 2         no              no      no      no      no        0.7
#
#    ALK_PHOSPHATE  SGOT  ALBUMIN  PROTIME HISTOLOGY  Class
# 0           85.0  18.0      4.0      NaN        no      1
# 1          135.0  42.0      3.5      NaN        no      1
# 2           96.0  32.0      4.0      NaN        no      1

# %% [markdown]
# Notamos que:
# Os valores numéricos são AGE, BILIRUBIN, ALK_PHOSPHATE, SGOT, ALBUMIN, PROTIME, e Class.
# Enquanto os categóricos são SEX, STEROID, ANTIVIRALS, FATIGUE, MALAISE, ANOREXIA, LIVER_BIG, LIVER_FIRM, SPLEEN_PALPABLE, SPIDERS, ASCITES, VARICES.

# %% [markdown]
# Questão 03.
# Realize o pré-processamento do dataset fornecido.
#
# Para isso, você deve:
#
# Para as variáveis numéricas: substitua os valores faltantes utilizando a estratégia de média (sklearn.impute.SimpleImputer).
# Para as variáveis categóricas: substitua os valores faltantes utilizando a estratégia de mais frequentes (sklearn.impute.SimpleImputer).
# Por fim, apresente os resultados, comprovando que a imputação e transformações foram feitas corretamente.

# %%
from sklearn.impute import SimpleImputer as si

# %%
imputer = si(strategy='mean')
numericas = ['AGE', 'BILIRUBIN', 'ALK_PHOSPHATE', 'SGOT', 'ALBUMIN', 'PROTIME', 'Class']
imputer = si(strategy='mean')
imputer.fit(df[numericas])
df[numericas] = imputer.transform(df[numericas])

imputer = si(strategy='most_frequent')
categoricas = ['SEX', 'STEROID', 'ANTIVIRALS', 'FATIGUE', 'MALAISE', 'ANOREXIA', 'LIVER_BIG', 'LIVER_FIRM', 'SPLEEN_PALPABLE', 'SPIDERS', 'ASCITES', 'VARICES']
imputer.fit(df[categoricas])
df[categoricas] = imputer.transform(df[categoricas])

df
# Out:
#       AGE     SEX STEROID ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_BIG  \
# 0    30.0    male      no         no      no      no       no        no
# 1    50.0  female      no         no     yes      no       no        no
# 2    78.0  female     yes         no     yes      no       no       yes
# 3    31.0  female     yes        yes      no      no       no       yes
# 4    34.0  female     yes         no      no      no       no       yes
# ..    ...     ...     ...        ...     ...     ...      ...       ...
# 150  46.0  female     yes         no     yes     yes      yes       yes
# 151  44.0  female     yes         no     yes      no       no       yes
# 152  61.0  female      no         no     yes     yes       no        no
# 153  53.0    male      no         no     yes      no       no       yes
# 154  43.0  female     yes         no     yes      no       no       yes
#
#     LIVER_FIRM SPLEEN_PALPABLE SPIDERS ASCITES VARICES  BILIRUBIN  \
# ...

# %% [markdown]
# Questão 04
#
# Calcule a matriz de correlação somente das variáveis. Determine quantas variáveis poderemos descartar e identifique quais são elas.

# %%
matriz_corr = df.select_dtypes(include=['number']).corr()
matriz_corr
# Out:
#                     AGE  BILIRUBIN  ALK_PHOSPHATE      SGOT   ALBUMIN  \
# AGE            1.000000   0.122884       0.008076  0.081052 -0.246169
# BILIRUBIN      0.122884   1.000000       0.157982  0.232610 -0.370712
# ALK_PHOSPHATE  0.008076   0.157982       1.000000  0.193969 -0.338158
# SGOT           0.081052   0.232610       0.193969  1.000000 -0.115455
# ALBUMIN       -0.246169  -0.370712      -0.338158 -0.115455  1.000000
# PROTIME       -0.153312  -0.220977      -0.189331 -0.137698  0.301497
# Class         -0.219647  -0.450470      -0.141005 -0.075579  0.465827
#
#                 PROTIME     Class
# AGE           -0.153312 -0.219647
# BILIRUBIN     -0.220977 -0.450470
# ALK_PHOSPHATE -0.189331 -0.141005
# SGOT          -0.137698 -0.075579
# ALBUMIN        0.301497  0.465827
# PROTIME        1.000000  0.307238
# Class          0.307238  1.000000

# %% [markdown]
# Notamos que nenhuma correlação está acima de 90%, portanto acredito que não devemos descartar nenhum atributo, mas se fosse necessário, escolheria descartar uma entre Class/SGOT com -0.075579 de correlação.

# %% [markdown]
# Questão 05
#
# Determine as 03 variáveis com menor correlação com a variável Class (pandas.DataFrame.corr).
#
# Caso queiramos estudar a relação da variável Class com as outras variáveis, por que seria interessante desconsiderar essas 10 variáveis identificadas?
#
# Lembre-se que heatmaps (seaborn.heatmap) podem auxiliar a visualização.

# %%
matriz_corr['Class'].abs().nsmallest(3)
# Out:
# SGOT             0.075579
# ALK_PHOSPHATE    0.141005
# AGE              0.219647
# Name: Class, dtype: float64

# %%
import seaborn as sns
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# O cálculo da matriz de correlação quantifica a relação linear entre as variáveis, analisar todas as correlações dos atributos uma a uma seria impraticável, faria mais sentido buscar correlações mais próximas para serem estudadas, tanto positiva quanto negativa. Ou seja os valores mais próximos de -1 e 1, mas que não sejam quase os mesmos(algo em torno de 80%-90% de correlação) seriam mais interessantes, no heatmap encontramos eles com as cores vermelho e azul mais intensas.

# %% [markdown]
# Questão 06
#
# Com as 03 varíaveis identificadas na questão anterior, crie um novo dataset que não contenha essas 10 váriaveis.
#
# Apresente as 5 primeiras linhas do novo dataset criado.
#
# Lembre-se que o numpy permite indexar colunas/linhas utilizando arrays.

# %%
df_new = df.drop(['SGOT' , 'ALK_PHOSPHATE', 'AGE'], axis=1)
df_new.head(5)
# Out:
#       SEX STEROID ANTIVIRALS FATIGUE MALAISE ANOREXIA LIVER_BIG LIVER_FIRM  \
# 0    male      no         no      no      no       no        no         no
# 1  female      no         no     yes      no       no        no         no
# 2  female     yes         no     yes      no       no       yes         no
# 3  female     yes        yes      no      no       no       yes         no
# 4  female     yes         no      no      no       no       yes         no
#
#   SPLEEN_PALPABLE SPIDERS ASCITES VARICES  BILIRUBIN  ALBUMIN    PROTIME  \
# 0              no      no      no      no        1.0      4.0  61.852273
# 1              no      no      no      no        0.9      3.5  61.852273
# 2              no      no      no      no        0.7      4.0  61.852273
# 3              no      no      no      no        0.7      4.0  80.000000
# 4              no      no      no      no        1.0      4.0  61.852273
#
#   HISTOLOGY  Class
# 0        no    1.0
# 1        no    1.0
# ...
